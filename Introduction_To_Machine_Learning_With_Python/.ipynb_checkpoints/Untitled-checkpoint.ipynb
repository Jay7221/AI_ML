# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_frame = pd.DataFrame(
    {
        'Age' : [66, 52, 22, 25, 44, 39, 26, 40, 53, 64, 58, 33],
        'Number of cars owned' : [1, 2, 0, 1, 0, 1, 1, 3, 2, 2, 2, 1],
        'Owns house' : [True, True, False, False, False, True, False, True, True, True, True, False],
        'Number of children' : [2, 3, 0, 1, 2, 2, 2, 1, 2, 3, 2, 1],
        'Martial Status' : ['widowed', 'married', 'married','single','divorced','married','single', 'married',
                           'divorced', 'divorced', 'married', 'single'],
        "Owns a dog" : ['no', 'no', 'yes', 'no', 'yes','yes', 'no', 'yes', 'no', 'no', 'yes', 'no'],
        'Bought a boat' : ['yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'yes', 'no'],
    }
)

# %%
display(data_frame)
# Out:
#     Age  Number of cars owned  Owns house  Number of children Martial Status  \
# 0    66                     1        True                   2        widowed
# 1    52                     2        True                   3        married
# 2    22                     0       False                   0        married
# 3    25                     1       False                   1         single
# 4    44                     0       False                   2       divorced
# 5    39                     1        True                   2        married
# 6    26                     1       False                   2         single
# 7    40                     3        True                   1        married
# 8    53                     2        True                   2       divorced
# 9    64                     2        True                   3       divorced
# 10   58                     2        True                   2        married
# ...
